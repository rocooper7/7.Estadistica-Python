# %%
#Distribuciones Discretas
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Distribución de Bernulli
from scipy.stats import bernoulli     #Se puede sacar tambien con numpy (np.random.normal)
p = 0.3      #Probabilidad de exito
data = bernoulli.rvs(p, size = 100)
len(data)
# Out:
# 100

# %%
import numpy as np
np.unique(data,return_counts=True)
# Out:
# (array([0, 1]), array([66, 34], dtype=int64))

# %%
import pandas as pd
pd.Series(data).value_counts()
# Out:
# 0    66
# 1    34
# dtype: int64

# %%
mean, var, skew, kurt = bernoulli.stats(p, moments = 'mvsk')
mean, var, skew, kurt
# Out:
# (array(0.3), array(0.21), array(0.87287156), array(-1.23809524))

# %%
import seaborn as sns

ax = sns.distplot( data, bins = 30, kde = False, color = 'blue')    #Displot == histogram de seaborn
ax.set( xlabel = 'Distribucion Bernoulli', ylabel = 'Frecuencia' )
ax.axvline(x = mean, linestyle = '--', label = 'Media' )
ax.legend();

# %%
# Distribución Binomial
from scipy.stats import binom
p = 0.3
n = 10
data = binom.rvs(p = p, n= n, size = 100)
len(data)
# Out:
# 100

# %%
data
# Out:
# array([2, 2, 4, 1, 4, 1, 3, 1, 3, 2, 2, 5, 3, 4, 2, 3, 2, 2, 4, 3, 2, 5,
#        5, 4, 1, 5, 5, 5, 3, 3, 2, 3, 2, 2, 3, 3, 4, 4, 2, 6, 2, 4, 4, 3,
#        1, 2, 4, 1, 1, 2, 2, 4, 2, 1, 7, 4, 1, 1, 1, 4, 3, 3, 1, 1, 2, 3,
#        3, 5, 3, 3, 4, 3, 1, 2, 2, 2, 3, 1, 1, 4, 5, 3, 2, 1, 4, 5, 2, 1,
#        2, 4, 4, 5, 2, 7, 4, 4, 4, 1, 1, 1])

# %%
pd.Series(data).value_counts()
# Out:
# 2    25
# 4    21
# 1    21
# 3    20
# 5    10
# 7     2
# 6     1
# dtype: int64

# %%
mean, var, skew, kurt = binom.stats(p = p, n = n , moments = 'mvsk')
mean, var, skew, kurt
# Out:
# (array(3.), array(2.1), array(0.27602622), array(-0.12380952))

# %%
ax = sns.distplot( data, bins = 30, kde = False, color = 'blue') 
ax.set( xlabel = 'Distribucion binomial', ylabel = 'Frecuencia' )
ax.axvline(x = mean, linestyle = '--', label = 'Media' )
ax.legend();

# %%
#Distribución Binomial Negativa
from scipy.stats import nbinom
p = 0.3
n = 10
data = nbinom.rvs(p = p, n= n, size = 100)
len(data)
data
# Out:
# array([23, 40, 23, 24, 20, 29, 12, 22, 13, 30, 14, 24, 15, 25, 15, 10,  9,
#        26, 24, 23, 22, 47, 49, 51, 31, 23, 16, 23, 26, 18, 24, 28, 21, 27,
#        22, 27, 13, 27, 54, 23, 21, 23, 23, 26, 23, 26, 38, 18, 11, 21, 21,
#        22, 10, 24, 35, 29, 17, 26, 19, 22, 22, 25, 27, 30, 31, 32, 36, 51,
#        39, 10, 25, 33, 22, 21, 28, 18, 25, 19, 21, 23, 40, 47, 22, 34,  9,
#        26, 23, 24, 15, 13, 14, 26, 40, 20, 50, 13, 34, 10, 29, 24])

# %%
pd.Series(data).value_counts().head()
# Out:
# 23    11
# 22     8
# 26     7
# 24     7
# 21     6
# dtype: int64

# %%
mean, var, skew, kurt = binom.stats(p = p, n = n , moments = 'mvsk')
mean, var, skew, kurt
# Out:
# (array(3.), array(2.1), array(0.27602622), array(-0.12380952))

# %%
ax = sns.distplot( data, bins = 30, kde = False, color = 'blue') 
ax.set( xlabel = 'Distribucion binomial negativa', ylabel = 'Frecuencia' )
ax.axvline(x = mean, linestyle = '--', label = 'Media' )
ax.legend();

# %%
from scipy.stats import poisson
lambda_p = 100   #Unidades de tiempo
data = poisson.rvs(mu = lambda_p, size = 100)
len(data)
data
# Out:
# array([ 99, 122, 120, 114,  94,  97,  91,  94, 106, 110, 108, 111,  95,
#         91, 104,  89, 108, 100,  86,  89, 104, 104, 108, 109,  87,  99,
#         87, 104, 105,  75, 101,  97, 107,  94, 109,  92,  82,  98,  95,
#        106, 107,  73,  84, 101, 102,  95, 110, 101, 123, 106, 104, 103,
#         90, 109, 109, 100,  87, 108,  98, 108,  98, 125, 104, 115, 112,
#        102,  89, 104, 114,  88, 117, 106,  99,  97,  93, 107,  98, 122,
#         93,  98,  94, 109,  91, 113, 115,  96, 103,  88, 123, 107, 105,
#         82, 102,  89,  90, 113, 102,  95,  98, 103])

# %%
pd.Series(data).value_counts().head()
# Out:
# 104    7
# 98     6
# 109    5
# 108    5
# 89     4
# dtype: int64

# %%
mean, var, skew, kurt = poisson.stats(mu =lambda_p, moments = 'mvsk')
mean, var, skew, kurt
# Out:
# (array(100.), array(100.), array(0.1), array(0.01))

# %%
ax = sns.distplot( data, bins = 30, kde = False, color = 'blue') 
ax.set( xlabel = 'Distribucion poisson', ylabel = 'Frecuencia' )
ax.axvline(x = mean, linestyle = '--', label = 'Media' )
ax.legend();

# %%
#Distribuciones Continuas
#Distribución Uniforme
from scipy.stats import uniform
data = uniform.rvs(size = 100000000)
len(data)
# Out:
# 100000000

# %%
mean, var, skew, kurt = uniform.stats( moments = 'mvsk')
mean, var, skew, kurt
# Out:
# (array(0.5), array(0.08333333), array(0.), array(-1.2))

# %%
ax = sns.distplot( data, bins = 500, kde = False, color = 'blue') 
ax.set( xlabel = 'Distribucion uniform 0 -1 ', ylabel = 'Frecuencia' )
ax.axvline(x = mean, linestyle = '--', label = 'Media' )
ax.legend();

# %%
#Distribucion Exponencial
from scipy.stats import expon
data = expon.rvs(size = 100000000)
len(data)
# Out:
# 100000000

# %%
mean, var, skew, kurt = expon.stats( moments = 'mvsk')
mean, var, skew, kurt
# Out:
# (array(1.), array(1.), array(2.), array(6.))

# %%
ax = sns.distplot( data, bins = 500, kde = False, color = 'blue') 
ax.set( xlabel = 'Distribucion Exponencial ', ylabel = 'Frecuencia' )
ax.axvline(x = mean, linestyle = '--', label = 'Media' )
ax.legend();

# %%
#Distribución Normal
from scipy.stats import norm
#mean = 0
#var = 1
data = norm.rvs(size = 100000000)
len(data)
# Out:
# 100000000

# %%
mean, var, skew, kurt = norm.stats( moments = 'mvsk')
mean, var, skew, kurt
# Out:
# (array(0.), array(1.), array(0.), array(0.))

# %%
ax = sns.distplot( data, bins = 500, kde = False, color = 'blue') 
ax.set( xlabel = 'Distribucion Normal Estandar ', ylabel = 'Frecuencia' )
ax.axvline(x = mean, linestyle = '--', label = 'Media' )
ax.legend();
